# %%
# Out:
# fullSet, iter:0 i:0,pairs changed 1
# fullSet, iter:1 i:1,pairs changed 1
# fullSet, iter:2 i:2,pairs changed 2
# fullSet, iter:3 i:3,pairs changed 3
# fullSet, iter:4 i:4,pairs changed 3
# fullSet, iter:5 i:5,pairs changed 4
# fullSet, iter:6 i:6,pairs changed 4
# j not moving enough
# fullSet, iter:7 i:7,pairs changed 4
# fullSet, iter:8 i:8,pairs changed 4
# j not moving enough
# fullSet, iter:9 i:9,pairs changed 4
# fullSet, iter:10 i:10,pairs changed 5
# fullSet, iter:11 i:11,pairs changed 5
# fullSet, iter:12 i:12,pairs changed 5
# fullSet, iter:13 i:13,pairs changed 6
# L == H
# fullSet, iter:14 i:14,pairs changed 6
# fullSet, iter:15 i:15,pairs changed 7
# fullSet, iter:16 i:16,pairs changed 8
# fullSet, iter:17 i:17,pairs changed 9
# fullSet, iter:18 i:18,pairs changed 9
# fullSet, iter:19 i:19,pairs changed 9
# fullSet, iter:20 i:20,pairs changed 9
# fullSet, iter:21 i:21,pairs changed 10
# j not moving enough
# fullSet, iter:22 i:22,pairs changed 10
# j not moving enough
# ...
